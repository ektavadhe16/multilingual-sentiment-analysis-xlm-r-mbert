# %% [markdown]
# <a href="https://colab.research.google.com/github/ektavadhe16/multilingual-sentiment-analysis-xlm-r-mbert/blob/main/notebooks/audio_preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello Ekta!")
# Out:
# Hello Ekta!

# %%
print('sad')
# Out:
# sad
